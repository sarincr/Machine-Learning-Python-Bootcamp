# %% [markdown]
# <a href="https://colab.research.google.com/github/sarincr/Machine-Learning-Python-Bootcamp/blob/master/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import io

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcc6991a-b52b-43e9-9950-432ab66ff100" name="files[]" multiple disabled />
#      <output id="result-dcc6991a-b52b-43e9-9950-432ab66ff100">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data.csv

# %%
df = pd.read_csv(io.StringIO(uploaded['Data.csv'].decode('utf-8')))

# %%
df.head()

# %%
df["time"]=pd.to_datetime(df["time"],infer_datetime_format=True)

# %%
df["time"]

# %%
indset=df.set_index(["time"])

# %%
indset

# %%
plt.plot(indset)

# %%
rlm=indset.rolling(window=902).mean()

# %%
rls=indset.rolling(window=902).std()

# %%
rlm

# %%
rls

# %%
og=plt.plot(indset, color="red",label="Original")

# %%
mn=plt.plot(rls, color="blue",label="Original")
st=plt.plot(rlm, color="green",label="Original")

# %%
from statsmodels.tsa.stattools import adfuller

# %%
print("DF Test Resulst")
dftest=adfuller(indset["power (W)"], autolag="AIC")
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
dfoutput
