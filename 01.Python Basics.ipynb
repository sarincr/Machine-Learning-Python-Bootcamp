# %%
print("Hello Python!")
#Print Python
# Out:
# Hello Python!

# %%
x=10
print(x)
# Out:
# 10

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=20

# %%
b
# Out:
# 20

# %%
a+b
# Out:
# 30

# %%
c=a+b

# %%
c
# Out:
# 30

# %%
k="Python"

# %%
print(k)
# Out:
# Python

# %%
k+" "+"program"
# Out:
# 'Python program'

# %%
a, b = 1, 2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
x = 4
y = x + 1
x = 2
print(x, y)
# Out:
# 2 5

# %%
x, y = 2, 6
x, y = y, x + 2
print(x, y)

# %%
4.6+5.2
# Out:
# 9.8

# %%
2+1
# Out:
# 3

# %%
2/1
# Out:
# 2.0

# %%
2*3
# Out:
# 6

# %%
10%3
# Out:
# 1

# %%
10-25
# Out:
# -15

# %%
7 + 2 + 5 - 3
# Out:
# 11

# %%
(2 + 3)*4
# Out:
# 20

# %%
x = "hello"
y = 'world'

# %%
x+y
# Out:
# 'helloworld'

# %%
def square(x):
    y=x+x
    return(y)

# %%
square(10)
# Out:
# 20

# %%
square(2) + square(3)
# Out:
# 10

# %%
def sum_of_squares(x, y):
    return square(x) + square(y)

# %%
sum_of_squares(2, 3)
# Out:
# 10

# %%
f = square

# %%
f(4)
# Out:
# 8

# %%
def fxy(f, x, y):
    return f(x) + f(y)

# %%
fxy(square, 2, 3)
# Out:
# 10

# %%
x = 0
y = 0
def incr(x):
    y = x + 1
    return y 
incr(5)
print(x, y)
# Out:
# 0 0

# %%
pi = 3.14
def area(r):
    return pi*r*r

# %%
numcalls = 0
def square(x):
    global numcalls
    numcalls = numcalls + 1
    return(x*x)
print(square(5))
# Out:
# 25

# %%
x = 1
def f():
    return x
print(x)
print(f())
# Out:
# 1
# 1

# %%
max(1,2,3,4,5,6,7)
# Out:
# 7

# %%
min(1,2,3,4,5,6)
# Out:
# 1

# %%
len("hello world")
# Out:
# 11

# %%
int("50")
# Out:
# 50

# %%
int(5.22222)
# Out:
# 5

# %%
k="Hellow"

# %%
j=str("Python")

# %%
k+j
# Out:
# 'HellowPython'

# %%
x = "hello"

# %%
x.upper()
# Out:
# 'HELLO'

# %%
x.lower()
# Out:
# 'hello'

# %%
2 < 3
# Out:
# True

# %%
2 > 3
# Out:
# False

# %%
x = 5

# %%
2 < x < 10
# Out:
# True

# %%
2 < 3 < 4 < 5 < 6
# Out:
# True

# %%
"python" > "perl"
# Out:
# True
